# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/tarasbohdan/Desktop/Experiments-AAAI-24

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'StudentPerformance'
# EXPERIMENT_SESSION_UUID = 'b98a24d4-5c64-41a9-aa71-e6263eb3e009'
# EXPERIMENT_SESSION_UUID = '4cfe1f1a-acee-4f52-987f-9fa64345ca4d'
# EXPERIMENT_SESSION_UUID = '090abd0e-ab4d-4db4-a97b-60ed17c0a814' # several seeds, test (not tuned)


EXPERIMENT_SESSION_UUID = '429e1647-70bc-4a6a-bd5f-7513ec18ac6b'
SENSITIVE_ATTRS = ['sex']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (190, 20)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#                    Metric              Model_Name  \
# 0                Accuracy  RandomForestClassifier
# 1                Accuracy  RandomForestClassifier
# 2                Accuracy  RandomForestClassifier
# 3                Accuracy  RandomForestClassifier
# 4                Accuracy  RandomForestClassifier
# 5                Accuracy  RandomForestClassifier
# 6                Accuracy  RandomForestClassifier
# 7                Accuracy  RandomForestClassifier
# 8                Accuracy  RandomForestClassifier
# 9                Accuracy  RandomForestClassifier
# 10  Aleatoric_Uncertainty  RandomForestClassifier
# 11  Aleatoric_Uncertainty  RandomForestClassifier
# 12  Aleatoric_Uncertainty  RandomForestClassifier
# 13  Aleatoric_Uncertainty  RandomForestClassifier
# 14  Aleatoric_Uncertainty  RandomForestClassifier
# 15  Aleatoric_Uncertainty  RandomForestClassifier
# 16  Aleatoric_Uncertainty  RandomForestClassifier
# 17  Aleatoric_Uncertainty  RandomForestClassifier
# 18  Aleatoric_Uncertainty  RandomForestClassifier
# 19  Aleatoric_Uncertainty  RandomForestClassifier
#
#                                          Model_Params        Dataset_Name  \
# 0   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 1   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 2   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 11  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 12  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 13  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
#
#     Num_Estimators Tag Record_Create_Date_Time  \
# 0               50  OK 2023-10-31 12:25:57.559
# 1               50  OK 2023-10-31 12:29:29.819
# 2               50  OK 2023-10-31 12:32:46.184
# 3               50  OK 2023-10-31 12:36:04.126
# 4               50  OK 2023-10-31 12:39:24.506
# 5               50  OK 2023-10-31 12:42:14.729
# 6               50  OK 2023-10-31 12:45:47.915
# 7               50  OK 2023-10-31 12:48:56.292
# 8               50  OK 2023-10-31 12:52:14.840
# 9               50  OK 2023-10-31 12:55:45.494
# 10              50  OK 2023-10-31 12:25:57.559
# 11              50  OK 2023-10-31 12:29:29.819
# 12              50  OK 2023-10-31 12:32:46.184
# 13              50  OK 2023-10-31 12:36:04.126
# 14              50  OK 2023-10-31 12:39:24.506
# 15              50  OK 2023-10-31 12:42:14.729
# 16              50  OK 2023-10-31 12:45:47.915
# 17              50  OK 2023-10-31 12:48:56.292
# 18              50  OK 2023-10-31 12:52:14.840
# 19              50  OK 2023-10-31 12:55:45.494
#
#                             Session_Uuid Experiment_Iteration  \
# 0   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 1   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 2   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 3   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 4   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 5   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 6   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 7   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 8   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 9   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 10  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 11  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 12  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 13  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 14  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 15  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 16  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 17  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 18  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 19  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
#
#     Dataset_Split_Seed  Model_Init_Seed  \
# 0                  300              300
# 1                  300              300
# 2                  300              300
# 3                  300              300
# 4                  300              300
# 5                  300              300
# 6                  300              300
# 7                  300              300
# 8                  300              300
# 9                  300              300
# 10                 300              300
# 11                 300              300
# 12                 300              300
# 13                 300              300
# 14                 300              300
# 15                 300              300
# 16                 300              300
# 17                 300              300
# 18                 300              300
# 19                 300              300
#
#                  Fair_Intervention_Params_Lst  Intervention_Param   overall  \
# 0   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                 5.0  0.000000
# 1   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                10.0  0.974790
# 2   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                15.0  0.941176
# 3   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                20.0  0.983193
# 4   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                25.0  0.983193
# 5   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                30.0  0.000000
# 6   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                35.0  0.991597
# 7   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                40.0  0.000000
# 8   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                45.0  1.000000
# 9   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0  0.991597
# 10  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                 5.0  0.000000
# 11  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                10.0  0.126724
# 12  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                15.0  0.460363
# 13  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                20.0  0.087467
# 14  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                25.0  0.162096
# 15  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                30.0  0.000000
# 16  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                35.0  0.169906
# 17  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                40.0  0.000000
# 18  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                45.0  0.155409
# 19  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0  0.150207
#
#      sex_dis  sex_dis_correct  sex_dis_incorrect  sex_priv  sex_priv_correct  \
# 0   0.000000              NaN           0.000000  0.000000               NaN
# 1   0.983871         1.000000           0.000000  0.964912          1.000000
# 2   0.935484         1.000000           0.000000  0.947368          1.000000
# 3   0.983871         1.000000           0.000000  0.982456          1.000000
# 4   0.983871         1.000000           0.000000  0.982456          1.000000
# 5   0.000000              NaN           0.000000  0.000000               NaN
# 6   0.983871         1.000000           0.000000  1.000000          1.000000
# 7   0.000000              NaN           0.000000  0.000000               NaN
# 8   1.000000         1.000000                NaN  1.000000          1.000000
# 9   1.000000         1.000000                NaN  0.982456          1.000000
# 10  0.000000              NaN           0.000000  0.000000               NaN
# 11  0.091791         0.079597           0.835667  0.164721          0.143731
# 12  0.436717         0.404189           0.908366  0.486082          0.462650
# 13  0.101057         0.087864           0.905823  0.072686          0.062935
# 14  0.136759         0.123634           0.937413  0.189656          0.180012
# 15  0.000000              NaN           0.000000  0.000000               NaN
# 16  0.165125         0.152751           0.919944  0.175106          0.175106
# 17  0.000000              NaN           0.000000  0.000000               NaN
# 18  0.185726         0.185726                NaN  0.122432          0.122432
# 19  0.161294         0.161294                NaN  0.138148          0.124777
#
#     sex_priv_incorrect
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             0.000000
# 4             0.000000
# 5             0.000000
# 6                  NaN
# 7             0.000000
# 8                  NaN
# 9             0.000000
# 10            0.000000
# 11            0.741922
# 12            0.907858
# 13            0.618725
# 14            0.729719
# 15            0.000000
# 16                 NaN
# 17            0.000000
# 18                 NaN
# 19            0.886925

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_7') & (df.Intervention_Param == 0.1)].T
# Out:
# Empty DataFrame
# Columns: []
# Index: [Metric, Model_Name, Model_Params, Dataset_Name, Num_Estimators, Tag, Record_Create_Date_Time, Session_Uuid, Experiment_Iteration, Dataset_Split_Seed, Model_Init_Seed, Fair_Intervention_Params_Lst, Intervention_Param, overall, sex_dis, sex_dis_correct, sex_dis_incorrect, sex_priv, sex_priv_correct, sex_priv_incorrect]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier'].keys()
# Out:
# dict_keys(['Exp_iter_3'])

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_3'][50].head()
# Out:
#                    Metric              Model_Name  \
# 9                Accuracy  RandomForestClassifier
# 19  Aleatoric_Uncertainty  RandomForestClassifier
# 29                     F1  RandomForestClassifier
# 39                    FNR  RandomForestClassifier
# 49                    FPR  RandomForestClassifier
#
#                                          Model_Params        Dataset_Name  \
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 29  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 39  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 49  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
#
#     Num_Estimators Tag Record_Create_Date_Time  \
# 9               50  OK 2023-10-31 12:55:45.494
# 19              50  OK 2023-10-31 12:55:45.494
# 29              50  OK 2023-10-31 12:55:45.494
# 39              50  OK 2023-10-31 12:55:45.494
# 49              50  OK 2023-10-31 12:55:45.494
#
#                             Session_Uuid Experiment_Iteration  \
# 9   429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 19  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 29  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 39  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
# 49  429e1647-70bc-4a6a-bd5f-7513ec18ac6b           Exp_iter_3
#
#     Dataset_Split_Seed  Model_Init_Seed  \
# 9                  300              300
# 19                 300              300
# 29                 300              300
# 39                 300              300
# 49                 300              300
#
#                  Fair_Intervention_Params_Lst  Intervention_Param   overall  \
# 9   [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0  0.991597
# 19  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0  0.150207
# 29  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0  0.979592
# 39  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0  0.000000
# 49  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0  0.010526
#
#      sex_dis  sex_dis_correct  sex_dis_incorrect  sex_priv  sex_priv_correct  \
# 9   1.000000         1.000000                NaN  0.982456          1.000000
# 19  0.161294         0.161294                NaN  0.138148          0.124777
# 29  1.000000         1.000000                NaN  0.956522          1.000000
# 39  0.000000         0.000000                NaN  0.000000          0.000000
# 49  0.000000         0.000000                NaN  0.021739          0.000000
#
#     sex_priv_incorrect
# 9             0.000000
# 19            0.886925
# 29            0.000000
# 39                 NaN
# 49            1.000000

# %% [markdown]
#     ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0                 Accuracy_Parity  RandomForestClassifier
# 1    Aleatoric_Uncertainty_Parity  RandomForestClassifier
# 2     Aleatoric_Uncertainty_Ratio  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4              Equalized_Odds_FNR  RandomForestClassifier
# 5              Equalized_Odds_FPR  RandomForestClassifier
# 6              Equalized_Odds_TPR  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                   Jitter_Parity  RandomForestClassifier
# 9           Label_Stability_Ratio  RandomForestClassifier
# 10     Overall_Uncertainty_Parity  RandomForestClassifier
# 11      Overall_Uncertainty_Ratio  RandomForestClassifier
# 12  Statistical_Parity_Difference  RandomForestClassifier
# 13                     Std_Parity  RandomForestClassifier
# 14                      Std_Ratio  RandomForestClassifier
# 0                 Accuracy_Parity  RandomForestClassifier
# 1    Aleatoric_Uncertainty_Parity  RandomForestClassifier
# 2     Aleatoric_Uncertainty_Ratio  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4              Equalized_Odds_FNR  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param Group  Metric_Value
# 0            Exp_iter_3                 5.0   sex      0.000000
# 1            Exp_iter_3                 5.0   sex      0.000000
# 2            Exp_iter_3                 5.0   sex           NaN
# 3            Exp_iter_3                 5.0   sex           NaN
# 4            Exp_iter_3                 5.0   sex      0.000000
# 5            Exp_iter_3                 5.0   sex           NaN
# 6            Exp_iter_3                 5.0   sex      0.000000
# 7            Exp_iter_3                 5.0   sex      0.000000
# 8            Exp_iter_3                 5.0   sex      0.000000
# 9            Exp_iter_3                 5.0   sex      1.000000
# 10           Exp_iter_3                 5.0   sex      0.000000
# 11           Exp_iter_3                 5.0   sex           NaN
# 12           Exp_iter_3                 5.0   sex      0.000000
# 13           Exp_iter_3                 5.0   sex      0.000000
# 14           Exp_iter_3                 5.0   sex           NaN
# 0            Exp_iter_3                10.0   sex      0.018959
# 1            Exp_iter_3                10.0   sex     -0.072929
# 2            Exp_iter_3                10.0   sex      0.557256
# 3            Exp_iter_3                10.0   sex      0.975177
# 4            Exp_iter_3                10.0   sex      0.000000

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Std', 'Label_Stability'],
                                                  subgroup='sex_dis')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='sex_dis')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='sex_priv')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='sex',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_TPR', 'Equalized_Odds_FPR', 'Std_Parity', 'Label_Stability_Ratio'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_group_metrics_line_band_plot(group='sex',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Disparate_Impact', 'Accuracy_Parity'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Label_Stability',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Overall_Uncertainty',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)
