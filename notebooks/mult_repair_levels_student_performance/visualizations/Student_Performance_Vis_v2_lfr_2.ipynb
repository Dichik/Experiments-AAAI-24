# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/tarasbohdan/Desktop/Experiments-AAAI-24

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'StudentPerformance'
# EXPERIMENT_SESSION_UUID = 'b98a24d4-5c64-41a9-aa71-e6263eb3e009'
# EXPERIMENT_SESSION_UUID = '4cfe1f1a-acee-4f52-987f-9fa64345ca4d'
# EXPERIMENT_SESSION_UUID = '090abd0e-ab4d-4db4-a97b-60ed17c0a814' # several seeds, test (not tuned)


# EXPERIMENT_SESSION_UUID = '91249614-e7df-4b80-8c4e-110ef587b414'
EXPERIMENT_SESSION_UUID = '6f0b4970-ea21-4e40-a946-5fe50a4a3565'
SENSITIVE_ATTRS = ['sex']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (1463, 20)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#       Metric              Model_Name  \
# 0   Accuracy  RandomForestClassifier
# 1   Accuracy  RandomForestClassifier
# 2   Accuracy  RandomForestClassifier
# 3   Accuracy  RandomForestClassifier
# 4   Accuracy  RandomForestClassifier
# 5   Accuracy  RandomForestClassifier
# 6   Accuracy  RandomForestClassifier
# 7   Accuracy  RandomForestClassifier
# 8   Accuracy  RandomForestClassifier
# 9   Accuracy  RandomForestClassifier
# 10  Accuracy  RandomForestClassifier
# 11  Accuracy  RandomForestClassifier
# 12  Accuracy  RandomForestClassifier
# 13  Accuracy  RandomForestClassifier
# 14  Accuracy  RandomForestClassifier
# 15  Accuracy  RandomForestClassifier
# 16  Accuracy  RandomForestClassifier
# 17  Accuracy  RandomForestClassifier
# 18  Accuracy  RandomForestClassifier
# 19  Accuracy  RandomForestClassifier
#
#                                          Model_Params        Dataset_Name  \
# 0   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 1   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 2   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 11  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 12  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 13  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
#
#     Num_Estimators Tag Record_Create_Date_Time  \
# 0              200  OK 2023-11-04 11:41:38.919
# 1              200  OK 2023-11-04 11:44:49.298
# 2              200  OK 2023-11-04 11:47:58.662
# 3              200  OK 2023-11-04 11:51:01.358
# 4              200  OK 2023-11-04 11:54:13.894
# 5              200  OK 2023-11-04 11:57:28.708
# 6              200  OK 2023-11-04 12:00:41.919
# 7              200  OK 2023-11-04 12:03:47.938
# 8              200  OK 2023-11-04 12:07:00.887
# 9              200  OK 2023-11-04 12:10:12.453
# 10             200  OK 2023-11-04 12:13:24.072
# 11             200  OK 2023-11-04 10:47:54.664
# 12             200  OK 2023-11-04 10:51:04.493
# 13             200  OK 2023-11-04 10:54:12.415
# 14             200  OK 2023-11-04 10:57:24.088
# 15             200  OK 2023-11-04 11:00:31.561
# 16             200  OK 2023-11-04 11:04:00.615
# 17             200  OK 2023-11-04 11:07:22.891
# 18             200  OK 2023-11-04 11:10:45.174
# 19             200  OK 2023-11-04 11:13:53.136
#
#                             Session_Uuid Experiment_Iteration  \
# 0   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 1   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 2   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 3   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 4   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 5   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 6   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 7   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 8   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 9   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 10  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_1
# 11  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_2
# 12  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_2
# 13  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_2
# 14  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_2
# 15  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_2
# 16  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_2
# 17  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_2
# 18  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_2
# 19  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_2
#
#     Dataset_Split_Seed  Model_Init_Seed  \
# 0                  100              100
# 1                  100              100
# 2                  100              100
# 3                  100              100
# 4                  100              100
# 5                  100              100
# 6                  100              100
# 7                  100              100
# 8                  100              100
# 9                  100              100
# 10                 100              100
# 11                 200              200
# 12                 200              200
# 13                 200              200
# 14                 200              200
# 15                 200              200
# 16                 200              200
# 17                 200              200
# 18                 200              200
# 19                 200              200
#
#                      Fair_Intervention_Params_Lst  Intervention_Param  \
# 0   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                 0.0
# 1   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                 5.0
# 2   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                10.0
# 3   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                15.0
# 4   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                20.0
# 5   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                25.0
# 6   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                30.0
# 7   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                35.0
# 8   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                40.0
# 9   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                45.0
# 10  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0
# 11  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                 0.0
# 12  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                 5.0
# 13  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                10.0
# 14  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                15.0
# 15  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                20.0
# 16  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                25.0
# 17  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                30.0
# 18  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                35.0
# 19  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                40.0
#
#      overall   sex_dis  sex_dis_correct  sex_dis_incorrect  sex_priv  \
# 0   0.756303  0.761905              1.0                0.0  0.750000
# 1   1.000000  1.000000              1.0                NaN  1.000000
# 2   0.991597  0.984127              1.0                0.0  1.000000
# 3   0.991597  1.000000              1.0                NaN  0.982143
# 4   0.991597  0.984127              1.0                0.0  1.000000
# 5   0.957983  0.968254              1.0                0.0  0.946429
# 6   0.949580  0.984127              1.0                0.0  0.910714
# 7   0.991597  1.000000              1.0                NaN  0.982143
# 8   0.957983  0.936508              1.0                0.0  0.982143
# 9   0.966387  0.984127              1.0                0.0  0.946429
# 10  0.915966  0.888889              1.0                0.0  0.946429
# 11  0.747899  0.678571              1.0                0.0  0.809524
# 12  0.966387  0.964286              1.0                0.0  0.968254
# 13  0.983193  0.982143              1.0                0.0  0.984127
# 14  0.991597  0.982143              1.0                0.0  1.000000
# 15  0.983193  1.000000              1.0                NaN  0.968254
# 16  0.974790  0.982143              1.0                0.0  0.968254
# 17  0.991597  1.000000              1.0                NaN  0.984127
# 18  0.932773  0.928571              1.0                0.0  0.936508
# 19  0.983193  1.000000              1.0                NaN  0.968254
#
#     sex_priv_correct  sex_priv_incorrect
# 0                1.0                 0.0
# 1                1.0                 NaN
# 2                1.0                 NaN
# 3                1.0                 0.0
# 4                1.0                 NaN
# 5                1.0                 0.0
# 6                1.0                 0.0
# 7                1.0                 0.0
# 8                1.0                 0.0
# 9                1.0                 0.0
# 10               1.0                 0.0
# 11               1.0                 0.0
# 12               1.0                 0.0
# 13               1.0                 0.0
# 14               1.0                 NaN
# 15               1.0                 0.0
# 16               1.0                 0.0
# 17               1.0                 0.0
# 18               1.0                 0.0
# 19               1.0                 0.0

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_7') & (df.Intervention_Param == 0.1)].T
# Out:
# Empty DataFrame
# Columns: []
# Index: [Metric, Model_Name, Model_Params, Dataset_Name, Num_Estimators, Tag, Record_Create_Date_Time, Session_Uuid, Experiment_Iteration, Dataset_Split_Seed, Model_Init_Seed, Fair_Intervention_Params_Lst, Intervention_Param, overall, sex_dis, sex_dis_correct, sex_dis_incorrect, sex_priv, sex_priv_correct, sex_priv_incorrect]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier'].keys()
# Out:
# dict_keys(['Exp_iter_1', 'Exp_iter_2', 'Exp_iter_3', 'Exp_iter_4', 'Exp_iter_5', 'Exp_iter_6'])

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_6'][50].head()
# Out:
#                     Metric              Model_Name  \
# 76                Accuracy  RandomForestClassifier
# 153  Aleatoric_Uncertainty  RandomForestClassifier
# 230                     F1  RandomForestClassifier
# 307                    FNR  RandomForestClassifier
# 384                    FPR  RandomForestClassifier
#
#                                           Model_Params        Dataset_Name  \
# 76   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 153  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 230  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 307  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 384  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
#
#      Num_Estimators Tag Record_Create_Date_Time  \
# 76              200  OK 2023-11-03 13:51:33.121
# 153             200  OK 2023-11-03 13:51:33.121
# 230             200  OK 2023-11-03 13:51:33.121
# 307             200  OK 2023-11-03 13:51:33.121
# 384             200  OK 2023-11-03 13:51:33.121
#
#                              Session_Uuid Experiment_Iteration  \
# 76   6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_6
# 153  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_6
# 230  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_6
# 307  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_6
# 384  6f0b4970-ea21-4e40-a946-5fe50a4a3565           Exp_iter_6
#
#      Dataset_Split_Seed  Model_Init_Seed  \
# 76                  600              600
# 153                 600              600
# 230                 600              600
# 307                 600              600
# 384                 600              600
#
#                       Fair_Intervention_Params_Lst  Intervention_Param  \
# 76   [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0
# 153  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0
# 230  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0
# 307  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0
# 384  [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]                50.0
#
#       overall   sex_dis  sex_dis_correct  sex_dis_incorrect  sex_priv  \
# 76   0.966387  0.967742          1.00000           0.000000  0.964912
# 153  0.279264  0.268858          0.24957           0.847481  0.290583
# 230  0.952381  0.965517          1.00000           0.000000  0.923077
# 307  0.024390  0.034483          0.00000           1.000000  0.000000
# 384  0.038462  0.030303          0.00000           1.000000  0.044444
#
#      sex_priv_correct  sex_priv_incorrect
# 76           1.000000            0.000000
# 153          0.266917            0.941417
# 230          1.000000            0.000000
# 307          0.000000                 NaN
# 384          0.000000            1.000000

# %% [markdown]
#     ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0                 Accuracy_Parity  RandomForestClassifier
# 1    Aleatoric_Uncertainty_Parity  RandomForestClassifier
# 2     Aleatoric_Uncertainty_Ratio  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4              Equalized_Odds_FNR  RandomForestClassifier
# 5              Equalized_Odds_FPR  RandomForestClassifier
# 6              Equalized_Odds_TPR  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                   Jitter_Parity  RandomForestClassifier
# 9           Label_Stability_Ratio  RandomForestClassifier
# 10     Overall_Uncertainty_Parity  RandomForestClassifier
# 11      Overall_Uncertainty_Ratio  RandomForestClassifier
# 12  Statistical_Parity_Difference  RandomForestClassifier
# 13                     Std_Parity  RandomForestClassifier
# 14                      Std_Ratio  RandomForestClassifier
# 0                 Accuracy_Parity  RandomForestClassifier
# 1    Aleatoric_Uncertainty_Parity  RandomForestClassifier
# 2     Aleatoric_Uncertainty_Ratio  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4              Equalized_Odds_FNR  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param Group  Metric_Value
# 0            Exp_iter_1                 0.0   sex      0.011905
# 1            Exp_iter_1                 0.0   sex      0.015818
# 2            Exp_iter_1                 0.0   sex      1.018520
# 3            Exp_iter_1                 0.0   sex      1.025568
# 4            Exp_iter_1                 0.0   sex     -0.029904
# 5            Exp_iter_1                 0.0   sex      0.070175
# 6            Exp_iter_1                 0.0   sex      0.029904
# 7            Exp_iter_1                 0.0   sex      0.002894
# 8            Exp_iter_1                 0.0   sex      0.006829
# 9            Exp_iter_1                 0.0   sex      0.989775
# 10           Exp_iter_1                 0.0   sex      0.017815
# 11           Exp_iter_1                 0.0   sex      1.020132
# 12           Exp_iter_1                 0.0   sex      0.032297
# 13           Exp_iter_1                 0.0   sex      0.003955
# 14           Exp_iter_1                 0.0   sex      1.042129
# 0            Exp_iter_1                 5.0   sex      0.000000
# 1            Exp_iter_1                 5.0   sex      0.003186
# 2            Exp_iter_1                 5.0   sex      3.278795
# 3            Exp_iter_1                 5.0   sex      1.000000
# 4            Exp_iter_1                 5.0   sex      0.000000

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Std', 'Label_Stability'],
                                                  subgroup='sex_dis')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='sex_dis')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='sex_priv')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='sex',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_TPR', 'Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Std_Parity', 'Label_Stability_Ratio'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_group_metrics_line_band_plot(group='sex',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Disparate_Impact', 'Accuracy_Parity'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Label_Stability',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Std',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Overall_Uncertainty',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Aleatoric_Uncertainty',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)
