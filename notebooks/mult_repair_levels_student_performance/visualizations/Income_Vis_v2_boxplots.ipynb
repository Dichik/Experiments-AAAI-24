# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/tarasbohdan/Desktop/Experiments-AAAI-24

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
EXPERIMENT_NAME = 'mult_repair_levels_student_performance'
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_GA_2018_Income'
EXPERIMENT_SESSION_UUID = '012d073d-00aa-4cd1-b3fe-5545796c43ad'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (114, 32)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#                    Metric              Model_Name  \
# 0                Accuracy  RandomForestClassifier
# 1                Accuracy  RandomForestClassifier
# 2                Accuracy  RandomForestClassifier
# 3                Accuracy  RandomForestClassifier
# 4                Accuracy  RandomForestClassifier
# 5                Accuracy  RandomForestClassifier
# 6   Aleatoric_Uncertainty  RandomForestClassifier
# 7   Aleatoric_Uncertainty  RandomForestClassifier
# 8   Aleatoric_Uncertainty  RandomForestClassifier
# 9   Aleatoric_Uncertainty  RandomForestClassifier
# 10  Aleatoric_Uncertainty  RandomForestClassifier
# 11  Aleatoric_Uncertainty  RandomForestClassifier
# 12                     F1  RandomForestClassifier
# 13                     F1  RandomForestClassifier
# 14                     F1  RandomForestClassifier
# 15                     F1  RandomForestClassifier
# 16                     F1  RandomForestClassifier
# 17                     F1  RandomForestClassifier
# 18                    FNR  RandomForestClassifier
# 19                    FNR  RandomForestClassifier
#
#                                          Model_Params        Dataset_Name  \
# 0   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 1   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 2   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 11  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 12  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 13  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  StudentPerformance
#
#     Num_Estimators Tag Record_Create_Date_Time  \
# 0               10  OK 2023-11-20 14:02:36.323
# 1               10  OK 2023-11-20 14:02:46.321
# 2               10  OK 2023-11-20 14:02:54.649
# 3               10  OK 2023-11-20 14:22:51.549
# 4               10  OK 2023-11-20 14:23:01.795
# 5               10  OK 2023-11-20 14:23:09.504
# 6               10  OK 2023-11-20 14:02:36.323
# 7               10  OK 2023-11-20 14:02:46.321
# 8               10  OK 2023-11-20 14:02:54.649
# 9               10  OK 2023-11-20 14:22:51.549
# 10              10  OK 2023-11-20 14:23:01.795
# 11              10  OK 2023-11-20 14:23:09.504
# 12              10  OK 2023-11-20 14:02:36.323
# 13              10  OK 2023-11-20 14:02:46.321
# 14              10  OK 2023-11-20 14:02:54.649
# 15              10  OK 2023-11-20 14:22:51.549
# 16              10  OK 2023-11-20 14:23:01.795
# 17              10  OK 2023-11-20 14:23:09.504
# 18              10  OK 2023-11-20 14:02:36.323
# 19              10  OK 2023-11-20 14:02:46.321
#
#                             Session_Uuid Experiment_Iteration  \
# 0   012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
# 1   012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
# 2   012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
# 3   012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_4
# 4   012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_4
# 5   012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_4
# 6   012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
# 7   012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
# 8   012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
# 9   012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_4
# 10  012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_4
# 11  012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_4
# 12  012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
# 13  012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
# 14  012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
# 15  012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_4
# 16  012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_4
# 17  012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_4
# 18  012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
# 19  012d073d-00aa-4cd1-b3fe-5545796c43ad           Exp_iter_3
#
#     Dataset_Split_Seed  ...  SEX&RAC1P_priv SEX&RAC1P_priv_correct  \
# 0                  300  ...             1.0                    1.0
# 1                  300  ...             1.0                    1.0
# 2                  300  ...             1.0                    1.0
# 3                  400  ...             1.0                    1.0
# 4                  400  ...             1.0                    1.0
# 5                  400  ...             1.0                    1.0
# 6                  300  ...             0.0                    0.0
# 7                  300  ...             0.0                    0.0
# 8                  300  ...             0.0                    0.0
# 9                  400  ...             0.0                    0.0
# 10                 400  ...             0.0                    0.0
# 11                 400  ...             0.0                    0.0
# 12                 300  ...             NaN                    NaN
# 13                 300  ...             NaN                    NaN
# 14                 300  ...             NaN                    NaN
# 15                 400  ...             NaN                    NaN
# 16                 400  ...             NaN                    NaN
# 17                 400  ...             NaN                    NaN
# 18                 300  ...             NaN                    NaN
# 19                 300  ...             NaN                    NaN
#
#    SEX&RAC1P_priv_incorrect  SEX_dis  SEX_dis_correct  SEX_dis_incorrect  \
# 0                       NaN      1.0              1.0                NaN
# 1                       NaN      1.0              1.0                NaN
# 2                       NaN      1.0              1.0                NaN
# 3                       NaN      1.0              1.0                NaN
# 4                       NaN      1.0              1.0                NaN
# 5                       NaN      1.0              1.0                NaN
# 6                       NaN      0.0              0.0                NaN
# 7                       NaN      0.0              0.0                NaN
# 8                       NaN      0.0              0.0                NaN
# 9                       NaN      0.0              0.0                NaN
# 10                      NaN      0.0              0.0                NaN
# 11                      NaN      0.0              0.0                NaN
# 12                      NaN      NaN              NaN                NaN
# 13                      NaN      NaN              NaN                NaN
# 14                      NaN      NaN              NaN                NaN
# 15                      NaN      NaN              NaN                NaN
# 16                      NaN      NaN              NaN                NaN
# 17                      NaN      NaN              NaN                NaN
# 18                      NaN      NaN              NaN                NaN
# 19                      NaN      NaN              NaN                NaN
#
#     SEX_priv  SEX_priv_correct  SEX_priv_incorrect  overall
# 0        1.0               1.0                 NaN      1.0
# 1        1.0               1.0                 NaN      1.0
# 2        1.0               1.0                 NaN      1.0
# 3        1.0               1.0                 NaN      1.0
# 4        1.0               1.0                 NaN      1.0
# 5        1.0               1.0                 NaN      1.0
# 6        0.0               0.0                 NaN      0.0
# 7        0.0               0.0                 NaN      0.0
# 8        0.0               0.0                 NaN      0.0
# 9        0.0               0.0                 NaN      0.0
# 10       0.0               0.0                 NaN      0.0
# 11       0.0               0.0                 NaN      0.0
# 12       NaN               NaN                 NaN      NaN
# 13       NaN               NaN                 NaN      NaN
# 14       NaN               NaN                 NaN      NaN
# 15       NaN               NaN                 NaN      NaN
# 16       NaN               NaN                 NaN      NaN
# 17       NaN               NaN                 NaN      NaN
# 18       NaN               NaN                 NaN      NaN
# 19       NaN               NaN                 NaN      NaN
#
# [20 rows x 32 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.1)].T
# Out:
# Empty DataFrame
# Columns: []
# Index: [Metric, Model_Name, Model_Params, Dataset_Name, Num_Estimators, Tag, Record_Create_Date_Time, Session_Uuid, Experiment_Iteration, Dataset_Split_Seed, Model_Init_Seed, Fair_Intervention_Params_Lst, Intervention_Param, RAC1P_dis, RAC1P_dis_correct, RAC1P_dis_incorrect, RAC1P_priv, RAC1P_priv_correct, RAC1P_priv_incorrect, SEX&RAC1P_dis, SEX&RAC1P_dis_correct, SEX&RAC1P_dis_incorrect, SEX&RAC1P_priv, SEX&RAC1P_priv_correct, SEX&RAC1P_priv_incorrect, SEX_dis, SEX_dis_correct, SEX_dis_incorrect, SEX_priv, SEX_priv_correct, SEX_priv_incorrect, overall]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier'].keys()
# Out:
# dict_keys(['Exp_iter_3', 'Exp_iter_4'])

# %%
# exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_2'][0.3].head(20)

# %%
# exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_2'][0.5].head()

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11     Overall_Uncertainty_Parity  RandomForestClassifier
# 12      Overall_Uncertainty_Ratio  RandomForestClassifier
# 13   Aleatoric_Uncertainty_Parity  RandomForestClassifier
# 14    Aleatoric_Uncertainty_Ratio  RandomForestClassifier
# 15             Equalized_Odds_TPR  RandomForestClassifier
# 16             Equalized_Odds_FPR  RandomForestClassifier
# 17             Equalized_Odds_FNR  RandomForestClassifier
# 18               Disparate_Impact  RandomForestClassifier
# 19  Statistical_Parity_Difference  RandomForestClassifier
#
#    Experiment_Iteration   Intervention_Param  Group  Metric_Value
# 0            Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           NaN
# 1            Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           0.0
# 2            Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           NaN
# 3            Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           NaN
# 4            Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           NaN
# 5            Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           0.0
# 6            Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           1.0
# 7            Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           0.0
# 8            Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           0.0
# 9            Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           NaN
# 10           Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           0.0
# 11           Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           0.0
# 12           Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           NaN
# 13           Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           0.0
# 14           Exp_iter_3  Ax=50, Az=10, Ay=10    SEX           NaN
# 15           Exp_iter_3  Ax=50, Az=10, Ay=10  RAC1P           NaN
# 16           Exp_iter_3  Ax=50, Az=10, Ay=10  RAC1P           0.0
# 17           Exp_iter_3  Ax=50, Az=10, Ay=10  RAC1P           NaN
# 18           Exp_iter_3  Ax=50, Az=10, Ay=10  RAC1P           NaN
# 19           Exp_iter_3  Ax=50, Az=10, Ay=10  RAC1P           NaN

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='sex_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='sex_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Std',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Label_Stability',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='sex',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_TPR', 'Equalized_Odds_FPR', 'Std_Parity', 'Label_Stability_Ratio'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_group_metrics_line_band_plot(group='sex',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FNR', 'Std_Parity', 'Label_Stability_Ratio'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Aleatoric_Uncertainty',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Overall_Uncertainty',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='IQR',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Std',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Std',
                                                   group='sex',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)
